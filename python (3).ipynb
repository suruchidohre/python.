# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python
#
#   a fundamental python library for numerical computing providing efficient tools for working with multidimesional arrays matrical and various mathematical operations making it a cornerstone of scientific compuuting and data analysis
#
# 2. How does broadcasting work in NumPy
#
#   numpy treats arrays with different shapes dring arithmetic operations suject to certain constraints the smaller array is "broadcast"across the larger array so that theyhave compatible shapes
#
# 3. What is a Pandas DataFrame
#
#  data is a 2-dimensional labeled data structure with columns of potentially different types you can think of it like a spreadsheel or sql table or a dict of series objects it is generally the most commonly used pandas object
#
# 4.Explain the use of the groupby() method in Pandas
#
#  the groupby () method in pandas allows you to split a dataframe into groups based onone or more columns apply functions to each group and then combine the results a process known as "split-apply-combine".
#
# 5. Why is Seaborn preferred for statistical visualizations
#
#   data visualization can be dne by seaborn and it can transform complex datasets into clear visual representations making it easier ti understand identify treand and relationships within the data this article will guide you through various plotting functions available in seaborn
#
# 6. What are the differences between NumPy arrays and Python lists
#
#   numpy arrats use fewer resources than pythonlists which becomes important when storind a large amount of data if you're working with thousands of elements python lists will be fine for most purposes
#
# 7.  What is a heatmap, and when should it be used
#
#  a graphical representation of data that used a system of color coding to represent different values heatmaps are used in various forms of analytics but are most commonly used to show user behavior on specific web pages or webpage templates
#
# 8. What does the term “vectorized operation” mean in NumPy
#
#  enable the use of efficient precomiled fuunction and mathematical operations on numpy arrays and datasequuences
#
# 9. How does Matplotlib differ from Plotly
#
#  both matplotlib and plotly have their distinct advantages matplotlib offers unmatched control and is prefect for creating static publiction-quality visuuals plotly on the other hand excels in interactivity and ease of use making it ideal for dynamic presentation and web applications
#
# 10. What is the significance of hierarchical indexing in Pandas
#
#  allowas yo to have multiple levels of indexing on an axis (row or column)
#
# 11. What is the role of Seaborn’s pairplot() function
#
#  seaborn's pairplot() function creates a grib of plots showing pairwise relationships between variable in a dataset with histograms or kenel density estimatea on the diagonal and scatterplots in the off-diagonal positions
#
# 12. What is the purpose of the describe() function in Pandas
#
#  pandas is used to generate descriptive statistics that summarize the central tendency dispersion and shape of a dataset's distribution providing a quuick overiem of the data
#
#
# 13. Why is handling missing data important in Pandas
#
#  isnull() notnull()
#
# 14. What are the benefits of using Plotly for data visualization
#
#  it allows you to create interactive and customizable charts easily plotly supports various chart types and integrates seamlessly with python ,R, and JavaScript its interactive features like zoom and hover enhance data exploration and you can share your visuualizations online making it great for collaboration
#
# 15. How does NumPy handle multidimensional arrays
#
#   a homogeneous block of dats organized in a multidimensional finite grib all elements of the arrays share the same data type also called dtype (integer floating -point number and so on) the shpe of the arrays is an n-tuple that gives the size of each axis
